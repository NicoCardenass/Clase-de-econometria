# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoCardenass/Clase-de-econometria/blob/main/Taller.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRESENTADO POR:**
#
# Maria Reales - 64141084
#
# Daniela Ramirez - 64201111
#
# Nicolás Cardenas - 63181008

# %%
# !pip install wooldRidge
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 39.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
import wooldridge as wd

# %%
df = wd.data ("wage1")

# %%
df
# Out:
#       wage  educ  exper  tenure  nonwhite  female  married  numdep  smsa  \
# 0     3.10    11      2       0         0       1        0       2     1
# 1     3.24    12     22       2         0       1        1       3     1
# 2     3.00    11      2       0         0       0        0       2     0
# 3     6.00     8     44      28         0       0        1       0     1
# 4     5.30    12      7       2         0       0        1       1     0
# ..     ...   ...    ...     ...       ...     ...      ...     ...   ...
# 521  15.00    16     14       2         0       1        1       2     0
# 522   2.27    10      2       0         0       1        0       3     0
# 523   4.67    15     13      18         0       0        1       3     0
# 524  11.56    16      5       1         0       0        1       0     0
# 525   3.50    14      5       4         1       1        0       2     0
#
#      northcen  ...  trcommpu  trade  services  profserv  profocc  clerocc  \
# ...

# %%
df = df[["wage", "educ", "exper"]]

# %%
df
# Out:
#       wage  educ  exper
# 0     3.10    11      2
# 1     3.24    12     22
# 2     3.00    11      2
# 3     6.00     8     44
# 4     5.30    12      7
# ..     ...   ...    ...
# 521  15.00    16     14
# 522   2.27    10      2
# 523   4.67    15     13
# 524  11.56    16      5
# 525   3.50    14      5
#
# [526 rows x 3 columns]

# %%
df['wage']
# Out:
# 0       3.10
# 1       3.24
# 2       3.00
# 3       6.00
# 4       5.30
#        ...
# 521    15.00
# 522     2.27
# 523     4.67
# 524    11.56
# 525     3.50
# Name: wage, Length: 526, dtype: float64

# %%
df.loc[:, ["educ", "exper"]]
# Out:
#      educ  exper
# 0      11      2
# 1      12     22
# 2      11      2
# 3       8     44
# 4      12      7
# ..    ...    ...
# 521    16     14
# 522    10      2
# 523    15     13
# 524    16      5
# 525    14      5
#
# [526 rows x 2 columns]

# %%
df.corr()
# Out:
#            wage      educ     exper
# wage   1.000000  0.405903  0.112903
# educ   0.405903  1.000000 -0.299542
# exper  0.112903 -0.299542  1.000000

# %%
#Convertir el dataframe en array
df_Array=np.array(df)

# %%
#Coeficientes
Coeficiente=np.corrcoef (df_Array.transpose())
pd.DataFrame(Coeficiente)
# Out:
#           0         1         2
# 0  1.000000  0.405903  0.112903
# 1  0.405903  1.000000 -0.299542
# 2  0.112903 -0.299542  1.000000

# %%
df.to_numpy()
# Out:
# array([[ 3.0999999 , 11.        ,  2.        ],
#        [ 3.24000001, 12.        , 22.        ],
#        [ 3.        , 11.        ,  2.        ],
#        ...,
#        [ 4.67000008, 15.        , 13.        ],
#        [11.56000042, 16.        ,  5.        ],
#        [ 3.5       , 14.        ,  5.        ]])

# %%
X=np.c_[np.ones(len(df_Array)),df_Array]
X
# Out:
# array([[ 1.        ,  3.0999999 , 11.        ,  2.        ],
#        [ 1.        ,  3.24000001, 12.        , 22.        ],
#        [ 1.        ,  3.        , 11.        ,  2.        ],
#        ...,
#        [ 1.        ,  4.67000008, 15.        , 13.        ],
#        [ 1.        , 11.56000042, 16.        ,  5.        ],
#        [ 1.        ,  3.5       , 14.        ,  5.        ]])
